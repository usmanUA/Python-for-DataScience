# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("life_expectancy_years.csv")
df.set_index("country", inplace=True)
years = df.columns.tolist()
new = df.T
new['Years'] = years
df = new.T
df = df.T

# %%
df['Years'].values
# Out:
# array(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807',
#        '1808', '1809', '1810', '1811', '1812', '1813', '1814', '1815',
#        '1816', '1817', '1818', '1819', '1820', '1821', '1822', '1823',
#        '1824', '1825', '1826', '1827', '1828', '1829', '1830', '1831',
#        '1832', '1833', '1834', '1835', '1836', '1837', '1838', '1839',
#        '1840', '1841', '1842', '1843', '1844', '1845', '1846', '1847',
#        '1848', '1849', '1850', '1851', '1852', '1853', '1854', '1855',
#        '1856', '1857', '1858', '1859', '1860', '1861', '1862', '1863',
#        '1864', '1865', '1866', '1867', '1868', '1869', '1870', '1871',
#        '1872', '1873', '1874', '1875', '1876', '1877', '1878', '1879',
#        '1880', '1881', '1882', '1883', '1884', '1885', '1886', '1887',
#        '1888', '1889', '1890', '1891', '1892', '1893', '1894', '1895',
#        '1896', '1897', '1898', '1899', '1900', '1901', '1902', '1903',
# ...

# %%
#sns.lineplot(data=df, x=df['Years'].values, y=df['Finland'].values)
sns.lineplot(data=df, x='Years', y='Finland')
plt.title(f"Finland Life Expectancy Projections")
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.show()

# %%
df
# Out:
#                       1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# country
# Afghanistan           28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1
# Angola                27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0
# Albania               35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4
# Andorra                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# United Arab Emirates  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7
# ...                    ...   ...   ...   ...   ...   ...   ...   ...   ...
# Samoa                 25.4  25.4  25.4  25.4  25.4  25.4  25.4  25.4  25.4
# Yemen                 23.4  23.4  23.4  23.4  23.4  23.4  23.4  23.4  23.4
# South Africa          33.5  33.5  33.5  33.5  33.5  33.5  33.5  33.5  33.5
# Zambia                32.6  32.6  32.6  32.6  32.6  32.6  32.6  32.6  32.6
# Zimbabwe              33.7  33.7  33.7  33.7  33.7  33.7  33.7  33.7  33.7
#
# ...

# %%
new = df.loc["Finland"]
new.values
# Out:
# array([36.6 , 40.3 , 39.2 , 28.5 , 35.9 , 39.8 , 38.8 , 36.6 , 12.5 ,
#        13.4 , 37.  , 30.7 , 37.6 , 34.2 , 35.  , 35.7 , 38.7 , 38.1 ,
#        37.2 , 35.  , 37.3 , 40.2 , 34.9 , 38.9 , 35.8 , 37.3 , 38.1 ,
#        42.2 , 40.6 , 36.3 , 36.3 , 34.  , 28.9 , 20.4 , 38.9 , 37.8 ,
#        30.8 , 34.4 , 40.1 , 42.7 , 41.5 , 41.  , 41.8 , 41.5 , 42.2 ,
#        40.9 , 38.6 , 40.8 , 40.2 , 39.4 , 37.4 , 40.3 , 32.9 , 33.6 ,
#        38.  , 31.9 , 30.  , 30.1 , 33.8 , 38.5 , 38.1 , 38.  , 34.1 ,
#        32.4 , 39.6 , 35.8 , 28.7 , 25.3 ,  8.11, 37.1 , 45.7 , 46.3 ,
#        44.1 , 39.5 , 39.1 , 40.7 , 41.8 , 39.  , 39.2 , 45.  , 39.7 ,
#        37.7 , 40.5 , 42.8 , 42.9 , 41.3 , 41.  , 45.6 , 45.2 , 45.  ,
#        44.7 , 42.6 , 39.8 , 43.4 , 45.3 , 47.7 , 46.6 , 48.2 , 48.1 ,
#        44.5 , 41.9 , 42.9 , 46.3 , 46.7 , 47.3 , 46.1 , 47.2 , 47.1 ,
#        46.2 , 48.8 , 48.6 , 48.8 , 49.2 , 49.2 , 49.8 , 49.7 , 48.1 ,
# ...

# %%
sns.barplot(x=df.columns, y=new.values)
plt.title(f"Finland Life Expectancy Projections")
plt.xlabel('haha')
plt.ylabel('hehe')
plt.show()
